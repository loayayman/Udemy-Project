# %% [markdown]
# Importing the packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# reading the file

# %%
df= pd.read_csv('udemy_courses_clean.csv')
df
# Out:
#       Unnamed: 0  course_id  \
# 0              0    1070968
# 1              1    1113822
# 2              2    1006314
# 3              3    1210588
# 4              4    1011058
# ...          ...        ...
# 3678        3678     775618
# 3679        3679    1088178
# 3680        3680     635248
# 3681        3681     905096
# 3682        3682     297602
#
#                                            course_title  \
# 0                    Ultimate Investment Banking Course
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4          How To Maximize Your Profits Trading Options
# ...                                                 ...
# 3678  Learn jQuery from Scratch - Master of JavaScri...
# 3679  How To Design A WordPress Website With No Codi...
# 3680                      Learn and Build using Polymer
# ...

# %% [markdown]
# exploring the data

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject',
#        'clean_course_title'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           3683 non-null   int64
#  1   course_id            3683 non-null   int64
#  2   course_title         3683 non-null   object
#  3   url                  3683 non-null   object
#  4   is_paid              3683 non-null   object
#  5   price                3683 non-null   object
#  6   num_subscribers      3683 non-null   int64
#  7   num_reviews          3683 non-null   int64
#  8   num_lectures         3683 non-null   int64
#  9   level                3683 non-null   object
#  10  content_duration     3683 non-null   object
#  11  published_timestamp  3683 non-null   object
#  12  subject              3683 non-null   object
#  13  clean_course_title   3663 non-null   object
# dtypes: int64(5), object(9)
# memory usage: 403.0+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# course_id               0
# course_title            0
# url                     0
# is_paid                 0
# price                   0
# num_subscribers         0
# num_reviews             0
# num_lectures            0
# level                   0
# content_duration        0
# published_timestamp     0
# subject                 0
# clean_course_title     20
# dtype: int64

# %% [markdown]
# #subject

# %%
df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
len(df['subject'].unique())
# Out:
# 4

# %%
df['subject'].value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1199
# Musical Instruments     681
# Graphic Design          603
# Name: count, dtype: int64

# %%
plt.figure(figsize= (10, 5))
df['subject'].value_counts().sort_values(ascending= False).plot(kind= 'bar')
plt.title('number of courses per subejct') 
plt.xticks(rotation = 0)
plt.show()

# %%
plt.figure(figsize= (10, 10))
df.groupby('subject')['num_subscribers'].sum().plot(kind= 'pie')
plt.title('number of subscribers per subject')
plt.show()

# %%
df['num_subscribers'].agg(['mean', 'max', 'min', 'sum', 'idxmax'])
# Out:
# mean      3.193371e+03
# max       2.689230e+05
# min       0.000000e+00
# sum       1.176119e+07
# idxmax    2.832000e+03
# Name: num_subscribers, dtype: float64

# %%
df.iloc[2832]
# Out:
# Unnamed: 0                                                          2832
# course_id                                                          41295
# course_title                        Learn HTML5 Programming From Scratch
# url                    https://www.udemy.com/learn-html5-programming-...
# is_paid                                                            False
# price                                                               Free
# num_subscribers                                                   268923
# num_reviews                                                         8629
# num_lectures                                                          45
# level                                                         All Levels
# content_duration                                              10.5 hours
# published_timestamp                                 2013-02-14T07:03:41Z
# subject                                                  Web Development
# ...

# %% [markdown]
# #level

# %%
df['level'].unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level', '52'], dtype=object)

# %%
f= (df['level']== '52')
df[f]
# Out:
#       Unnamed: 0  course_id  \
# 2066        2066      96698
#
#                                            course_title    url  \
# 2066  Learn Classical Guitar Technique and play 'Spa...  000!"
#
#                                           is_paid price  num_subscribers  \
# 2066  https://www.udemy.com/learnguitartoworship/  TRUE               30
#
#       num_reviews  num_lectures level content_duration published_timestamp  \
# 2066         1463            29    52   Beginner Level             3 hours
#
#                   subject                                 clean_course_title
# 2066  Musical Instruments  Learn Classical Guitar Technique play Spanish ...

# %%
len(df['level'].unique())
# Out:
# 5

# %%
df['level'].value_counts()
# Out:
# level
# All Levels            1932
# Beginner Level        1271
# Intermediate Level     421
# Expert Level            58
# 52                       1
# Name: count, dtype: int64

# %%
plt.figure(figsize= (10, 5))
df['level'].value_counts().plot(kind='bar')
plt.title('number of courses per level')
plt.xticks(rotation= 0)
plt.show()

# %%
df.groupby('level')['num_subscribers'].sum()
# Out:
# level
# 52                         30
# All Levels            6916112
# Beginner Level        4052843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
plt.figure(figsize= (10, 5))
df.groupby('level')['num_subscribers'].sum().sort_values(ascending= False).plot(kind= 'bar')
plt.title('number of subscribers per level')
plt.xticks(rotation= 0)
plt.show()

# %%
df.groupby('subject')['num_subscribers'].sum().sort_values(ascending =False)
# Out:
# subject
# Web Development        7980572
# Business Finance       1870747
# Graphic Design         1063148
# Musical Instruments     846719
# Name: num_subscribers, dtype: int64

# %%
plt.figure(figsize= (10, 5))
df.groupby('subject')['num_subscribers'].sum().sort_values(ascending =False).plot(kind='bar')
plt.title('number of subscribers per subject')
plt.xticks(rotation= 0)
plt.show()

# %%
plt.figure(figsize= (20, 10))
sns.barplot(x= 'level', y= 'num_subscribers', data=df, hue= 'subject', errorbar= None)
plt.show()

# %% [markdown]
# #lecture

# %%
def func_draw(x):
    plt.figure(figsize= (10, 5))
    sns.barplot(x= 'level', y=x, data=df, hue= 'subject', errorbar= None)
    plt.title('plot of {} per level per subject'.format(x))
    plt.show()
    
    #pie chart
    plt.figure(figsize= (5, 5))
    df.groupby('level')[x].sum().plot(kind='pie')
    plt.title('plot of {} per level'.format(x))
    plt.show()

# %%
func_draw('num_subscribers')

# %%
df['price'].dtype
# Out:
# dtype('O')

# %%
df['price'].unique()
# Out:
# array(['200', '75', '45', '95', '150', '65', '195', '30', '20', '50',
#        '175', '140', '115', '190', '125', '60', '145', '105', '155',
#        '185', '180', '120', '25', '160', '40', 'Free', '100', '90', '35',
#        '80', '70', '55', '165', '130', '85', '170', '110', '135', 'TRUE'],
#       dtype=object)

# %%
df['price'] = df['price'].str.replace('Free|TRUE','0', regex= True)

# %%
df['price'] = df['price'].astype(float)

# %%
df['price'].describe()
# Out:
# count    3683.000000
# mean       65.992398
# std        60.985586
# min         0.000000
# 25%        20.000000
# 50%        45.000000
# 75%        95.000000
# max       200.000000
# Name: price, dtype: float64

# %%
df['price'].idxmax()
# Out:
# 0

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                                             0
# course_id                                                        1070968
# course_title                          Ultimate Investment Banking Course
# url                    https://www.udemy.com/ultimate-investment-bank...
# is_paid                                                             True
# price                                                              200.0
# num_subscribers                                                     2147
# num_reviews                                                           23
# num_lectures                                                          51
# level                                                         All Levels
# content_duration                                               1.5 hours
# published_timestamp                                 2017-01-18T20:58:58Z
# subject                                                 Business Finance
# ...

# %% [markdown]
# profit = price * subscribers

# %%
df['profit'] = df['price'] * df['num_subscribers']

# %%
df['profit'].max()
# Out:
# np.float64(24316800.0)

# %%
df['profit'].idxmax()
# Out:
# 3235

# %%
df.iloc[3235]
# Out:
# Unnamed: 0                                                          3235
# course_id                                                         625204
# course_title                                  The Web Developer Bootcamp
# url                    https://www.udemy.com/the-web-developer-bootcamp/
# is_paid                                                             True
# price                                                              200.0
# num_subscribers                                                   121584
# num_reviews                                                        27445
# num_lectures                                                         342
# level                                                         All Levels
# content_duration                                                43 hours
# published_timestamp                                 2015-11-02T21:13:27Z
# subject                                                  Web Development
# ...

# %%
df['is_paid'].value_counts()
# Out:
# is_paid
# True                                           2738
# TRUE                                            634
# False                                           264
# FALSE                                            46
# https://www.udemy.com/learnguitartoworship/       1
# Name: count, dtype: int64

# %%
paid_dict= {'True': True, 
            'TRUE': True,
           'False' : False,
           'FALSE': False,
        'https://www.udemy.com/learnguitartoworship/' : True
           }

# %%
df['is_paid'] = df['is_paid'].map(paid_dict)

# %%
df['is_paid'].value_counts()
# Out:
# is_paid
# True     3373
# False     310
# Name: count, dtype: int64

# %%
df['is_paid'].value_counts().plot(kind= 'bar')
plt.show()

# %%
df['subject'].unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
plt.figure(figsize= (10, 5))
df.groupby('is_paid')['subject'].value_counts().plot(kind='bar')
plt.xticks(rotation= 10)
plt.show()

# %%
df['published_timestamp'].str.split('T')
# Out:
# 0       [2017-01-18, 20:58:58Z]
# 1       [2017-03-09, 16:34:20Z]
# 2       [2016-12-19, 19:26:30Z]
# 3       [2017-05-30, 20:07:24Z]
# 4       [2016-12-13, 14:57:18Z]
#                  ...
# 3678    [2016-06-14, 17:36:46Z]
# 3679    [2017-03-10, 22:24:30Z]
# 3680    [2015-12-30, 16:41:42Z]
# 3681    [2016-08-11, 19:06:15Z]
# 3682    [2014-09-28, 19:51:11Z]
# Name: published_timestamp, Length: 3683, dtype: object

# %%
df['puplished_date'] = df['published_timestamp'].str.split('T').str.get(0)

# %%
df['puplished_date']
# Out:
# 0       2017-01-18
# 1       2017-03-09
# 2       2016-12-19
# 3       2017-05-30
# 4       2016-12-13
#            ...
# 3678    2016-06-14
# 3679    2017-03-10
# 3680    2015-12-30
# 3681    2016-08-11
# 3682    2014-09-28
# Name: puplished_date, Length: 3683, dtype: object

# %%
df['puplished_date'] = df['puplished_date'].str.replace('3 hours','2017-01-18' )

# %%
df['puplished_date'] = pd.to_datetime(df['puplished_date'], format= '%Y-%m-%d')

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# course_id                       int64
# course_title                   object
# url                            object
# is_paid                          bool
# price                         float64
# num_subscribers                 int64
# num_reviews                     int64
# num_lectures                    int64
# level                          object
# content_duration               object
# published_timestamp            object
# subject                        object
# clean_course_title             object
# profit                        float64
# puplished_date         datetime64[ns]
# dtype: object

# %%
df['year'] = df['puplished_date'].dt.year

# %%
df['year']
# Out:
# 0       2017
# 1       2017
# 2       2016
# 3       2017
# 4       2016
#         ...
# 3678    2016
# 3679    2017
# 3680    2015
# 3681    2016
# 3682    2014
# Name: year, Length: 3683, dtype: int32

# %%
df['month'] = df['puplished_date'].dt.month

# %%
df['day'] = df['puplished_date'].dt.day

# %%
df['year'].unique()
# Out:
# array([2017, 2016, 2014, 2015, 2013, 2012, 2011], dtype=int32)

# %%
df.groupby('year')['num_subscribers'].sum().idxmax()
# Out:
# np.int32(2015)

# %%
df.groupby('year')['num_subscribers'].sum().plot(kind='bar')
plt.show()

# %%
sns.lineplot(x= 'year', y= 'num_subscribers', data=df, hue= 'subject', errorbar= None)
plt.title('plot of subscribtion per year per subject category')
plt.show()

# %%
sns.lineplot(x= df['year'], y= df['profit'], data= df, hue= df['subject'])
plt.show()

# %%
plt.figure(figsize= (15,10))
correlation_matrix =df.corr( numeric_only=True,method='pearson') 

sns.heatmap(correlation_matrix, annot=True , cmap= 'YlGnBu' , vmin= 0, vmax=1 )
plt.title('Correlation matric for Numeric features')
plt.show()

# %%
sns.lineplot(x= df['profit'], y= df['num_reviews'], data= df)
plt.title('profit vs number of reviews correlation')
plt.show()

# %%
sns.lineplot(x= df['profit'], y= df['num_lectures'], data= df)
plt.title('profit vs number of reviews correlation')
plt.show()
